# %%
model_path = 'overflow_saspeech_gold-February-13-2023_09+32AM-c7184dce/best_model.pth'
config_path = 'overflow_saspeech_gold-February-13-2023_09+32AM-c7184dce/config.json'
output_path = 'overflow_saspeech_gold-February-13-2023_09+32AM-c7184dce/outputs/output_1.wav'

text = 'ואיך זה גורם לך להרגיש?'

# %%
# !tts --text "{text}" \
      --model_path "{model_path}" \
      --config_path "{config_path}" \
      --out_path "{output_path}"
# Out:
#  > Using model: Overflow
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:True
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Text: ואיך זה גורם לך להרגיש?
#  > Text splitted to sentences.
# ['ואיך זה גורם לך להרגיש?']
# ואיך זה גורם לך להרגיש?
# ...

# %%
from IPython.display import Audio

sample_rate = 22050  # specify the sample rate of the audio file
Audio(output_path, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
